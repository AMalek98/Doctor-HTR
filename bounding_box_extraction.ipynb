# %% [markdown]
# # 📦 Bounding Box Extraction and Region Isolation Pipeline
#
# ## 📝 Purpose and Context
#
# This notebook implements a critical preprocessing step in the handwriting recognition pipeline, focusing on extracting individual word regions from images based on YOLO format bounding box annotations. This process transforms detection results into isolated word images suitable for OCR training and inference.
#
# ## 🎯 Strategic Importance
#
# **Primary Objective**: Convert YOLO detection outputs into individual word images for downstream text recognition tasks.
#
# **Key Benefits**:
# - **Dataset Preparation**: Creates training data for TrOCR and other OCR models
# - **Quality Control**: Ensures extracted regions contain meaningful text content
# - **Systematic Organization**: Maintains traceability between source annotations and extracted regions
# - **Scalable Processing**: Handles large document collections efficiently
#
# ## 🔄 Technical Workflow
#
# ### **Input Requirements**
# - **Label Files**: YOLO format annotations with normalized coordinates `[class, x_center, y_center, width, height]`
# - **Source Images**: Original scanned medical documents containing handwritten text
# - **Directory Structure**: Organized file system for systematic processing
#
# ### **Processing Pipeline**
# 1. **Coordinate Transformation**: Converts normalized YOLO coordinates to absolute pixel coordinates
# 2. **Boundary Validation**: Ensures bounding boxes remain within image dimensions
# 3. **Region Extraction**: Crops specified areas from source images
# 4. **File Organization**: Saves extracted regions with descriptive naming conventions
#
# ### **Output Structure**
# ```
# extracted_bounding_boxes/
# ├── image_name_1/
# │   ├── class_1.jpg
# │   ├── class_2.jpg
# │   └── ...
# ├── image_name_2/
# │   ├── class_1.jpg
# │   └── ...
# ```
#
# ## 📊 Quality Assurance Features
#
# **Coordinate Validation**:
# - Boundary checking to prevent out-of-bounds errors
# - Dimension validation for meaningful region sizes
# - Error handling for corrupted or missing data
#
# **Processing Verification**:
# - Progress tracking for large dataset processing
# - Error logging for failed extractions
# - File integrity checks for saved regions
#
# ## 🚀 Expected Outcomes
#
# - Clean, isolated word images ready for OCR training
# - Systematic dataset organization for machine learning workflows
# - Preserved image quality and text legibility
# - Comprehensive processing logs for debugging and validation
#
# ---

# %%
import os
import cv2

def create_output_directory(output_dir):
    """
    Creates output directory structure for extracted bounding box regions.
    
    Ensures the target directory exists and is ready for file output,
    creating nested directories as needed for organized storage.
    
    Args:
        output_dir (str): Path to the desired output directory
    
    Returns:
        None
    
    Raises:
        OSError: If directory creation fails due to permissions
    """
    try:
        os.makedirs(output_dir, exist_ok=True)
        print(f"✅ Output directory created: {output_dir}")
    except OSError as e:
        print(f"❌ Failed to create directory {output_dir}: {e}")
        raise

def validate_bounding_box(bbox_coords, image_shape):
    """
    Validates bounding box coordinates against image dimensions.
    
    Ensures that bounding box coordinates are within valid image bounds
    and that the box has positive dimensions.
    
    Args:
        bbox_coords (tuple): Bounding box coordinates (x1, y1, x2, y2)
        image_shape (tuple): Image dimensions (height, width, channels)
    
    Returns:
        bool: True if bounding box is valid, False otherwise
    """
    x1, y1, x2, y2 = bbox_coords
    height, width = image_shape[:2]
    
    # Check bounds and positive dimensions
    if (x1 >= 0 and y1 >= 0 and x2 <= width and y2 <= height and 
        x2 > x1 and y2 > y1):
        return True
    return False

def convert_yolo_to_pixel_coordinates(bbox_yolo, image_shape):
    """
    Converts YOLO normalized coordinates to pixel coordinates.
    
    Transforms normalized bounding box coordinates [x_center, y_center, width, height]
    to pixel coordinates [x1, y1, x2, y2] for image cropping operations.
    
    Args:
        bbox_yolo (tuple): YOLO format coordinates (x_center_norm, y_center_norm, width_norm, height_norm)
        image_shape (tuple): Image dimensions (height, width, channels)
    
    Returns:
        tuple: Pixel coordinates (x1, y1, x2, y2)
    """
    x_center_norm, y_center_norm, width_norm, height_norm = bbox_yolo
    height, width = image_shape[:2]
    
    # Convert to pixel coordinates
    x_center = int(x_center_norm * width)
    y_center = int(y_center_norm * height)
    width_pixels = int(width_norm * width)
    height_pixels = int(height_norm * height)
    
    # Calculate corner coordinates with boundary checking
    x1 = max(0, x_center - width_pixels // 2)
    y1 = max(0, y_center - height_pixels // 2)
    x2 = min(width, x_center + width_pixels // 2)
    y2 = min(height, y_center + height_pixels // 2)
    
    return (x1, y1, x2, y2)

def load_bounding_box_annotations(label_dir):
    """
    Loads and processes YOLO format bounding box annotations from label files.
    
    Reads annotation files and creates a structured dictionary mapping
    image names to their corresponding bounding box data.
    
    Args:
        label_dir (str): Directory containing YOLO format label files
    
    Returns:
        dict: Dictionary mapping image names to bounding box annotations
    """
    # Directory containing YOLO format label files
    label_dir = "enter your path here"  # Path to label files directory
    
    print(f"📂 Loading annotations from: {label_dir}")
    
    try:
        # Get all label files
        label_files = [f for f in os.listdir(label_dir) if f.endswith('.txt')]
        print(f"📊 Found {len(label_files)} label files")
        
        # Extract image names without extensions
        image_names = [os.path.splitext(filename)[0] for filename in label_files]
        
        # Initialize annotation dictionary
        image_bounding_boxes = {}
        
        # Process each label file
        for filename, image_name in zip(label_files, image_names):
            label_path = os.path.join(label_dir, filename)
            
            with open(label_path, "r", encoding='utf-8') as label_file:
                # Parse YOLO format: class x_center y_center width height
                bounding_boxes = []
                for line in label_file:
                    parts = line.strip().split()
                    if len(parts) >= 5:
                        class_label = parts[0]
                        coordinates = tuple(map(float, parts[1:5]))
                        bounding_boxes.append((class_label, coordinates))
                
                image_bounding_boxes[image_name] = bounding_boxes
        
        print(f"✅ Loaded annotations for {len(image_bounding_boxes)} images")
        return image_bounding_boxes
        
    except Exception as e:
        print(f"❌ Error loading annotations: {e}")
        return {}

def extract_and_save_bounding_boxes(image_dir, image_bounding_boxes, output_dir):
    """
    Extracts and saves bounding box regions from images based on annotations.
    
    Processes a collection of images and their corresponding bounding box annotations,
    extracting individual text regions and saving them as separate image files
    for downstream OCR or analysis tasks.
    
    Args:
        image_dir (str): Directory containing source images
        image_bounding_boxes (dict): Dictionary mapping image names to bounding box data
        output_dir (str): Directory for saving extracted regions
    
    Returns:
        dict: Processing statistics including success/failure counts
    """
    processing_stats = {
        'total_images': len(image_bounding_boxes),
        'processed_images': 0,
        'extracted_regions': 0,
        'failed_extractions': 0
    }
    
    print(f"🚀 Starting extraction process for {processing_stats['total_images']} images")
    
    # Process each image and its bounding boxes
    for image_filename, bounding_boxes_info in image_bounding_boxes.items():
        try:
            # Load source image
            image_path = os.path.join(image_dir, image_filename + '.jpg')
            if not os.path.exists(image_path):
                print(f"⚠️ Image not found: {image_path}")
                continue
                
            original_image = cv2.imread(image_path)
            if original_image is None:
                print(f"❌ Failed to load image: {image_path}")
                continue
            
            print(f"📸 Processing: {image_filename} ({len(bounding_boxes_info)} regions)")
            
            # Create output subdirectory for this image
            output_folder = os.path.join(output_dir, image_filename)
            create_output_directory(output_folder)
            
            # Process each bounding box for this image
            for line_number, bbox_info in enumerate(bounding_boxes_info, start=1):
                label, bbox = bbox_info
                
                # Convert YOLO coordinates to pixel coordinates
                pixel_coords = convert_yolo_to_pixel_coordinates(bbox, original_image.shape)
                
                # Validate bounding box
                if not validate_bounding_box(pixel_coords, original_image.shape):
                    print(f"⚠️ Invalid bounding box for {image_filename}, region {line_number}")
                    processing_stats['failed_extractions'] += 1
                    continue
                
                x1, y1, x2, y2 = pixel_coords
                
                # Extract bounding box region
                bounding_box_image = original_image[y1:y2, x1:x2]
                
                # Verify extracted region is not empty
                if bounding_box_image.size == 0:
                    print(f"⚠️ Empty region extracted for {image_filename}, region {line_number}")
                    processing_stats['failed_extractions'] += 1
                    continue
                
                # Save extracted region
                output_filename = f"{label}_{line_number}.jpg"
                output_path = os.path.join(output_folder, output_filename)
                
                success = cv2.imwrite(output_path, bounding_box_image)
                if success:
                    processing_stats['extracted_regions'] += 1
                else:
                    print(f"❌ Failed to save: {output_path}")
                    processing_stats['failed_extractions'] += 1
            
            processing_stats['processed_images'] += 1
            
        except Exception as e:
            print(f"❌ Error processing {image_filename}: {e}")
            continue
    
    return processing_stats

def run_bounding_box_extraction_pipeline():
    """
    Executes the complete bounding box extraction pipeline.
    
    Orchestrates the entire workflow from loading annotations to saving
    extracted regions, providing comprehensive processing statistics
    and error reporting.
    
    Returns:
        dict: Complete processing statistics and results summary
    """
    print("🚀 Starting Bounding Box Extraction Pipeline")
    print("=" * 60)
    
    # Configuration paths - update these with your actual paths
    label_dir = "enter your path here"      # Path to YOLO annotation files
    image_dir = "enter your path here"      # Path to source images
    output_dir = "enter your path here"     # Path for extracted regions
    
    print(f"📂 Label Directory: {label_dir}")
    print(f"📸 Image Directory: {image_dir}")
    print(f"💾 Output Directory: {output_dir}")
    print()
    
    try:
        # Step 1: Load bounding box annotations
        print("Step 1: Loading Bounding Box Annotations")
        print("-" * 40)
        image_bounding_boxes = load_bounding_box_annotations(label_dir)
        
        if not image_bounding_boxes:
            print("❌ No valid annotations found. Pipeline terminated.")
            return {'status': 'failed', 'reason': 'no_annotations'}
        
        print()
        
        # Step 2: Create output directory
        print("Step 2: Preparing Output Directory")
        print("-" * 40)
        create_output_directory(output_dir)
        print()
        
        # Step 3: Extract and save bounding box regions
        print("Step 3: Extracting Bounding Box Regions")
        print("-" * 40)
        stats = extract_and_save_bounding_boxes(image_dir, image_bounding_boxes, output_dir)
        
        # Step 4: Generate final report
        print()
        print("📊 Final Processing Report")
        print("=" * 40)
        print(f"Total Images: {stats['total_images']}")
        print(f"Successfully Processed: {stats['processed_images']}")
        print(f"Extracted Regions: {stats['extracted_regions']}")
        print(f"Failed Extractions: {stats['failed_extractions']}")
        
        # Calculate success rate
        if stats['extracted_regions'] > 0:
            success_rate = (stats['extracted_regions'] / 
                          (stats['extracted_regions'] + stats['failed_extractions'])) * 100
            print(f"Success Rate: {success_rate:.1f}%")
        
        print()
        print("✅ Bounding Box Extraction Pipeline Completed Successfully!")
        print(f"📁 Extracted regions saved to: {output_dir}")
        
        stats['status'] = 'completed'
        stats['output_directory'] = output_dir
        
        return stats
        
    except Exception as e:
        print(f"❌ Pipeline failed with error: {e}")
        return {'status': 'failed', 'error': str(e)}

# Execute the complete pipeline
if __name__ == "__main__":
    pipeline_results = run_bounding_box_extraction_pipeline()
